# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.size"] = "26"
#plt.rcParams['savefig.facecolor'] = "0.5"
plt.tight_layout()

# %%
bColor = "red"
oColor = "green"
hColor = "blue"

# %%
result = pd.read_csv(r"Substitution/foods_vary_l.csv")

# %%
result
# Out:
#                           Dataset  Number_Of_Candidates  Number_of_voters  \
# 0   adressa=8_ballot=10000000bs=4                     8                70
# 1   adressa=8_ballot=10000000bs=4                     8                70
# 2   adressa=8_ballot=10000000bs=4                     8                70
# 3   adressa=8_ballot=10000000bs=5                     8                70
# 4   adressa=8_ballot=10000000bs=5                     8                70
# 5   adressa=8_ballot=10000000bs=5                     8                70
# 6   adressa=8_ballot=10000000bs=6                     8                70
# 7   adressa=8_ballot=10000000bs=6                     8                70
# 8   adressa=8_ballot=10000000bs=6                     8                70
# 9   adressa=8_ballot=10000000bs=7                     8                70
# 10  adressa=8_ballot=10000000bs=7                     8                70
# 11  adressa=8_ballot=10000000bs=7                     8                70
# 12  adressa=8_ballot=10000000bs=8                     8                70
# 13  adressa=8_ballot=10000000bs=8                     8                70
# 14  adressa=8_ballot=10000000bs=8                     8                70
#
#     Max_Ballot_length  Preferred_winner  Upper_Bound  heuristicV1_margin  \
# 0                   4                 2            0                   0
# 1                   4                 1            0                   0
# 2                   4                 0            0                   0
# 3                   5                 2            0                   0
# 4                   5                 1            0                   0
# 5                   5                 0            0                   0
# 6                   6                 2            0                   0
# 7                   6                 1            0                   0
# 8                   6                 0            0                   0
# 9                   6                 2            0                   0
# 10                  6                 1            0                   0
# 11                  6                 0            0                   0
# 12                  6                 2            0                   0
# 13                  6                 1            0                   0
# 14                  6                 0            0                   0
#
#     Our_margin  Blom_margin  heuristicV1_runtime  ...  Blom_runtime  \
# 0          0.0          0.0             0.001594  ...      0.203197
# 1          0.0          0.0             0.001722  ...      0.222778
# 2          0.0          0.0             0.001731  ...      0.262814
# 3          0.0          0.0             0.001738  ...      0.206067
# 4          0.0          0.0             0.001594  ...      0.178354
# 5          0.0          0.0             0.001456  ...      0.168293
# 6          0.0          0.0             0.001402  ...      0.179211
# 7          0.0          0.0             0.001412  ...      0.211896
# 8          0.0          0.0             0.001662  ...      0.198128
# 9          0.0          0.0             0.001642  ...      0.189477
# 10         0.0          0.0             0.001551  ...      0.179094
# 11         0.0          0.0             0.003341  ...      0.282178
# 12         0.0          0.0             0.001931  ...      0.226877
# 13         0.0          0.0             0.001692  ...      0.191356
# 14         0.0          0.0             0.001704  ...      0.194243
#
#     Margin_Blom=Ours  Upper_bound_correct  HeuristicV1_equl_margin  \
# 0                  1                    1                        1
# 1                  1                    1                        1
# 2                  1                    1                        1
# 3                  1                    1                        1
# 4                  1                    1                        1
# 5                  1                    1                        1
# 6                  1                    1                        1
# 7                  1                    1                        1
# 8                  1                    1                        1
# 9                  1                    1                        1
# 10                 1                    1                        1
# 11                 1                    1                        1
# 12                 1                    1                        1
# 13                 1                    1                        1
# 14                 1                    1                        1
#
#     Our_number_LPS  Blom_number_LPS  Our_number_node_explored  \
# 0                1               43                        44
# 1                1               43                        44
# 2                1               43                        44
# 3                1               43                        44
# 4                1               43                        44
# 5                1               43                        44
# 6                1               43                        44
# 7                1               43                        44
# 8                1               43                        44
# 9                1               43                        44
# 10               1               43                        44
# 11               1               43                        44
# 12               1               43                        44
# 13               1               43                        44
# 14               1               43                        44
#
#     Blom_number_node_explored  Our_blom_lb_calls  Blom_Leaf_node_explored
# 0                          44                 42                        1
# 1                          44                 42                        1
# 2                          44                 42                        1
# 3                          44                 42                        1
# 4                          44                 42                        1
# 5                          44                 42                        1
# 6                          44                 42                        1
# 7                          44                 42                        1
# 8                          44                 42                        1
# 9                          44                 42                        1
# 10                         44                 42                        1
# 11                         44                 42                        1
# 12                         44                 42                        1
# 13                         44                 42                        1
# 14                         44                 42                        1
#
# [15 rows x 21 columns]

# %%
result['margin_difference'] = result['heuristicV1_margin'] - result['Blom_margin']

# %%
result
# Out:
#                           Dataset  Number_Of_Candidates  Number_of_voters  \
# 0   adressa=8_ballot=10000000bs=4                     8                70
# 1   adressa=8_ballot=10000000bs=4                     8                70
# 2   adressa=8_ballot=10000000bs=4                     8                70
# 3   adressa=8_ballot=10000000bs=5                     8                70
# 4   adressa=8_ballot=10000000bs=5                     8                70
# 5   adressa=8_ballot=10000000bs=5                     8                70
# 6   adressa=8_ballot=10000000bs=6                     8                70
# 7   adressa=8_ballot=10000000bs=6                     8                70
# 8   adressa=8_ballot=10000000bs=6                     8                70
# 9   adressa=8_ballot=10000000bs=7                     8                70
# 10  adressa=8_ballot=10000000bs=7                     8                70
# 11  adressa=8_ballot=10000000bs=7                     8                70
# 12  adressa=8_ballot=10000000bs=8                     8                70
# 13  adressa=8_ballot=10000000bs=8                     8                70
# 14  adressa=8_ballot=10000000bs=8                     8                70
#
#     Max_Ballot_length  Preferred_winner  Upper_Bound  heuristicV1_margin  \
# 0                   4                 2            0                   0
# 1                   4                 1            0                   0
# 2                   4                 0            0                   0
# 3                   5                 2            0                   0
# 4                   5                 1            0                   0
# 5                   5                 0            0                   0
# 6                   6                 2            0                   0
# 7                   6                 1            0                   0
# 8                   6                 0            0                   0
# 9                   6                 2            0                   0
# 10                  6                 1            0                   0
# 11                  6                 0            0                   0
# 12                  6                 2            0                   0
# 13                  6                 1            0                   0
# 14                  6                 0            0                   0
#
#     Our_margin  Blom_margin  heuristicV1_runtime  ...  Margin_Blom=Ours  \
# 0          0.0          0.0             0.001594  ...                 1
# 1          0.0          0.0             0.001722  ...                 1
# 2          0.0          0.0             0.001731  ...                 1
# 3          0.0          0.0             0.001738  ...                 1
# 4          0.0          0.0             0.001594  ...                 1
# 5          0.0          0.0             0.001456  ...                 1
# 6          0.0          0.0             0.001402  ...                 1
# 7          0.0          0.0             0.001412  ...                 1
# 8          0.0          0.0             0.001662  ...                 1
# 9          0.0          0.0             0.001642  ...                 1
# 10         0.0          0.0             0.001551  ...                 1
# 11         0.0          0.0             0.003341  ...                 1
# 12         0.0          0.0             0.001931  ...                 1
# 13         0.0          0.0             0.001692  ...                 1
# 14         0.0          0.0             0.001704  ...                 1
#
#     Upper_bound_correct  HeuristicV1_equl_margin  Our_number_LPS  \
# 0                     1                        1               1
# 1                     1                        1               1
# 2                     1                        1               1
# 3                     1                        1               1
# 4                     1                        1               1
# 5                     1                        1               1
# 6                     1                        1               1
# 7                     1                        1               1
# 8                     1                        1               1
# 9                     1                        1               1
# 10                    1                        1               1
# 11                    1                        1               1
# 12                    1                        1               1
# 13                    1                        1               1
# 14                    1                        1               1
#
#     Blom_number_LPS  Our_number_node_explored  Blom_number_node_explored  \
# 0                43                        44                         44
# 1                43                        44                         44
# 2                43                        44                         44
# 3                43                        44                         44
# 4                43                        44                         44
# 5                43                        44                         44
# 6                43                        44                         44
# 7                43                        44                         44
# 8                43                        44                         44
# 9                43                        44                         44
# 10               43                        44                         44
# 11               43                        44                         44
# 12               43                        44                         44
# 13               43                        44                         44
# 14               43                        44                         44
#
#     Our_blom_lb_calls  Blom_Leaf_node_explored  margin_difference
# 0                  42                        1                0.0
# 1                  42                        1                0.0
# 2                  42                        1                0.0
# 3                  42                        1                0.0
# 4                  42                        1                0.0
# 5                  42                        1                0.0
# 6                  42                        1                0.0
# 7                  42                        1                0.0
# 8                  42                        1                0.0
# 9                  42                        1                0.0
# 10                 42                        1                0.0
# 11                 42                        1                0.0
# 12                 42                        1                0.0
# 13                 42                        1                0.0
# 14                 42                        1                0.0
#
# [15 rows x 22 columns]

# %%
result.columns
# Out:
# Index(['Dataset', 'Number_Of_Candidates', 'Number_of_voters',
#        'Max_Ballot_length', 'Preferred_winner', 'Upper_Bound',
#        'heuristicV1_margin', 'Our_margin', 'Blom_margin',
#        'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime',
#        'Margin_Blom=Ours', 'Upper_bound_correct', 'HeuristicV1_equl_margin',
#        'Our_number_LPS', 'Blom_number_LPS', 'Our_number_node_explored',
#        'Blom_number_node_explored', 'Our_blom_lb_calls',
#        'Blom_Leaf_node_explored', 'margin_difference'],
#       dtype='object')

# %%
avg = result.groupby(['Max_Ballot_length'])['Dataset', 'Number_Of_Candidates', 'Number_of_voters',
       'Max_Ballot_length', 'Preferred_winner', 'Upper_Bound',
       'heuristicV1_margin', 'Our_margin', 'Blom_margin',
       'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime',
       'Margin_Blom=Ours', 'Upper_bound_correct', 'HeuristicV1_equl_margin',
       'Our_number_LPS', 'Blom_number_LPS', 'Our_number_node_explored',
       'Blom_number_node_explored', 'Our_blom_lb_calls',
       'Blom_Leaf_node_explored', 'margin_difference'].mean()
# Out:
# C:\Users\mouin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
avg.to_csv('tempAvgmovie=10.csv')

# %%
avgDf = pd.read_csv('tempAvgmovie=10.csv')
avgDf
# Out:
#    Max_Ballot_length  Number_Of_Candidates  Number_of_voters  \
# 0                  4                     8                70
# 1                  5                     8                70
# 2                  6                     8                70
#
#    Max_Ballot_length.1  Preferred_winner  Upper_Bound  heuristicV1_margin  \
# 0                    4                 1            0                   0
# 1                    5                 1            0                   0
# 2                    6                 1            0                   0
#
#    Our_margin  Blom_margin  heuristicV1_runtime  ...  Margin_Blom=Ours  \
# 0         0.0          0.0             0.001682  ...                 1
# 1         0.0          0.0             0.001596  ...                 1
# 2         0.0          0.0             0.001815  ...                 1
#
#    Upper_bound_correct  HeuristicV1_equl_margin  Our_number_LPS  \
# 0                    1                        1               1
# 1                    1                        1               1
# 2                    1                        1               1
#
#    Blom_number_LPS  Our_number_node_explored  Blom_number_node_explored  \
# 0               43                        44                         44
# 1               43                        44                         44
# 2               43                        44                         44
#
#    Our_blom_lb_calls  Blom_Leaf_node_explored  margin_difference
# 0                 42                        1                0.0
# 1                 42                        1                0.0
# 2                 42                        1                0.0
#
# [3 rows x 22 columns]

# %%
#import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()


x  = avgDf['Max_Ballot_length'].to_list()
y = avgDf['heuristicV1_runtime'].to_list()
z = avgDf['Our_runtime'].to_list()
u = avgDf['Blom_runtime'].to_list()


plt.plot(x,y,color=hColor,linewidth=4)
plt.plot(x,z,color=oColor,linewidth=4)
plt.plot(x,u,color=bColor,linewidth=4)
plt.tight_layout()
# create an index for each tick position

plt.ylabel('Time (s)')
plt.xlabel('Maximum ballot size (l)')
#plt.xticks([4,6,8,10,12], ['4','6','8','10','12'])
plt.ylim(-2*5/100,2)

plt.legend(["AlgApprx","AlgExact","Blom"],loc='upper left')
fig.savefig(r"Figures/substitution_food_n=8_vary_l_runtime.pdf",dpi=2024,bbox_inches='tight')
