# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.size"] = "26"
#plt.rcParams['savefig.facecolor'] = "0.5"
plt.tight_layout()

# %%
bColor = "red"
oColor = "green"
hColor = "blue"

# %%
result = pd.read_csv(r"Addition/movies_vary_n.csv")

# %%
result
# Out:
#                         Dataset  Number_Of_Candidates  Number_of_voters  \
# 0    movieLens_movie=9_ballot=4                     9               525
# 1    movieLens_movie=9_ballot=4                     9               525
# 2    movieLens_movie=9_ballot=4                     9               525
# 3    movieLens_movie=8_ballot=4                     8               523
# 4    movieLens_movie=8_ballot=4                     8               523
# 5    movieLens_movie=8_ballot=4                     8               523
# 6    movieLens_movie=7_ballot=4                     7               521
# 7    movieLens_movie=7_ballot=4                     7               521
# 8    movieLens_movie=7_ballot=4                     7               521
# 9    movieLens_movie=6_ballot=4                     6               517
# 10   movieLens_movie=6_ballot=4                     6               517
# 11   movieLens_movie=6_ballot=4                     6               517
# 12   movieLens_movie=5_ballot=4                     5               499
# 13   movieLens_movie=5_ballot=4                     5               499
# 14   movieLens_movie=5_ballot=4                     5               499
# 15   movieLens_movie=4_ballot=4                     4               472
# 16   movieLens_movie=4_ballot=4                     4               472
# 17  movieLens_movie=10_ballot=4                    10               528
# 18  movieLens_movie=10_ballot=4                    10               528
# 19  movieLens_movie=10_ballot=4                    10               528
# 20  movieLens_movie=10_ballot=4                    10               528
# 21  movieLens_movie=11_ballot=4                    11               530
# 22  movieLens_movie=11_ballot=4                    11               530
# 23  movieLens_movie=11_ballot=4                    11               530
# 24  movieLens_movie=11_ballot=4                    11               530
# 25  movieLens_movie=12_ballot=4                    12               541
# 26  movieLens_movie=12_ballot=4                    12               541
# 27  movieLens_movie=12_ballot=4                    12               541
# 28  movieLens_movie=12_ballot=4                    12               541
#
#     Max_Ballot_length Preferred_winner  Upper_Bound  heuristicV1_margin  \
# 0                   4           Action           71                  71
# 1                   4           Comedy           12                  12
# 2                   4            Crime           58                  58
# 3                   4           Action           71                  71
# 4                   4           Comedy           15                  15
# 5                   4            Crime           36                  36
# 6                   4           Action           69                  69
# 7                   4           Comedy            2                   2
# 8                   4            Crime           52                  52
# 9                   4           Action           69                  69
# 10                  4           Comedy            1                   1
# 11                  4            Crime           53                  53
# 12                  4           Comedy           28                  28
# 13                  4            Crime           92                  92
# 14                  4           Action           55                  55
# 15                  4           Comedy           28                  28
# 16                  4            Crime           92                  92
# 17                  4           Action           68                  68
# 18                  4           Comedy           11                  11
# 19                  4            Crime           58                  58
# 20                  4            Drama          107                 107
# 21                  4           Action           72                  72
# 22                  4           Comedy           11                  11
# 23                  4            Crime           36                  36
# 24                  4            Drama           96                  96
# 25                  4        Adventure            0                   0
# 26                  4           Action           48                  48
# 27                  4           Comedy           15                  15
# 28                  4            Crime           34                  34
#
#     Our_margin  Blom_margin  heuristicV1_runtime  ...  
# 5               0.658595         0.002107          0.121549
# 6               0.155242         0.001141          0.028857
# 7               0.028957         0.000757          0.023807
# 8               0.605972         0.000783          0.069490
# 9               0.047078         0.000554          0.005448
# 10              0.006843         0.000488          0.003818
# 11              0.157831         0.000497          0.019106
# 12              0.051885         0.000247          0.002191
# 13              0.192607         0.000556          0.005769
# 14              0.006643         0.000368          0.001789
# 15              0.020127         0.000121          0.000530
# 16              0.060964         0.000184          0.001242
# 17              2.663216         0.007482          0.401279
# 18              0.924406         0.001865          0.222401
# 19             21.093814         0.001986          1.440346
# 20             88.069943         0.000907          1.442926
# 21              4.099606         0.014342          0.617629
# 22              3.943242         0.001951          0.450820
# 23             12.023262         0.002014          3.490626
# 24            345.077007         0.001006          3.018612
# 25              0.000000         0.001163          0.003468
# 26           1011.977987         0.008372          9.098812
# 27            555.467151         0.003494          3.664426
# 28            107.659203         0.002729          8.620437
#
# [29 rows x 25 columns]

# %%
result['margin_difference'] = result['heuristicV1_margin'] - result['Blom_margin']

# %%
result
# Out:
#                         Dataset  Number_Of_Candidates  Number_of_voters  \
# 0    movieLens_movie=9_ballot=4                     9               525
# 1    movieLens_movie=9_ballot=4                     9               525
# 2    movieLens_movie=9_ballot=4                     9               525
# 3    movieLens_movie=8_ballot=4                     8               523
# 4    movieLens_movie=8_ballot=4                     8               523
# 5    movieLens_movie=8_ballot=4                     8               523
# 6    movieLens_movie=7_ballot=4                     7               521
# 7    movieLens_movie=7_ballot=4                     7               521
# 8    movieLens_movie=7_ballot=4                     7               521
# 9    movieLens_movie=6_ballot=4                     6               517
# 10   movieLens_movie=6_ballot=4                     6               517
# 11   movieLens_movie=6_ballot=4                     6               517
# 12   movieLens_movie=5_ballot=4                     5               499
# 13   movieLens_movie=5_ballot=4                     5               499
# 14   movieLens_movie=5_ballot=4                     5               499
# 15   movieLens_movie=4_ballot=4                     4               472
# 16   movieLens_movie=4_ballot=4                     4               472
# 17  movieLens_movie=10_ballot=4                    10               528
# 18  movieLens_movie=10_ballot=4                    10               528
# 19  movieLens_movie=10_ballot=4                    10               528
# 20  movieLens_movie=10_ballot=4                    10               528
# 21  movieLens_movie=11_ballot=4                    11               530
# 22  movieLens_movie=11_ballot=4                    11               530
# 23  movieLens_movie=11_ballot=4                    11               530
# 24  movieLens_movie=11_ballot=4                    11               530
# 25  movieLens_movie=12_ballot=4                    12               541
# 26  movieLens_movie=12_ballot=4                    12               541
# 27  movieLens_movie=12_ballot=4                    12               541
# 28  movieLens_movie=12_ballot=4                    12               541
#
#     Max_Ballot_length Preferred_winner  Upper_Bound  heuristicV1_margin  \
# 0                   4           Action           71                  71
# 1                   4           Comedy           12                  12
# 2                   4            Crime           58                  58
# 3                   4           Action           71                  71
# 4                   4           Comedy           15                  15
# 5                   4            Crime           36                  36
# 6                   4           Action           69                  69
# 7                   4           Comedy            2                   2
# 8                   4            Crime           52                  52
# 9                   4           Action           69                  69
# 10                  4           Comedy            1                   1
# 11                  4            Crime           53                  53
# 12                  4           Comedy           28                  28
# 13                  4            Crime           92                  92
# 10                        0             0.000782              0.006843
# 11                        0             0.008681              0.157831
# 12                        1             0.001556              0.051885
# 13                        7             0.009640              0.192607
# 14                        0             0.000747              0.006643
# 15                        1             0.000337              0.020127
# 16                        4             0.001459              0.060964
# 17                        4             0.254847              2.663216
# 18                        2             0.082776              0.924406
# 19                       20             2.081286             21.093814
# 20                      157             3.729324             88.069943
# 21                        4             0.406735              4.099606
# 22                        4             0.219042              3.943242
# 23                        0             1.899403             12.023262
# 24                      360             8.560890            345.077007
# 25                        0             0.000000              0.000000
# 26                      342            17.721562           1011.977987
# 27                      297             5.809444            555.467151
# 28                        0             7.854658            107.659203
#
#     Our_Time_lbcall  Blom_Time_lbcall  margin_difference
# 0          0.003458          0.242022                 71
# 1          0.001370          0.168647                 11
# 2          0.001447          0.510891                 22
# 3          0.002367          0.129455                 71
# 4          0.001092          0.106630                  9
# 5          0.002107          0.121549                  0
# 6          0.001141          0.028857                 69
# 7          0.000757          0.023807                  0
# 8          0.000783          0.069490                  0
# 9          0.000554          0.005448                 69
# 10         0.000488          0.003818                  0
# 11         0.000497          0.019106                  0
# 12         0.000247          0.002191                 28
# 13         0.000556          0.005769                  5
# 14         0.000368          0.001789                  0
# 15         0.000121          0.000530                 28
# 16         0.000184          0.001242                  5
# 17         0.007482          0.401279                 66
# 18         0.001865          0.222401                 11
# 19         0.001986          1.440346                 21
# 20         0.000907          1.442926                 14
# 21         0.014342          0.617629                 72
# 22         0.001951          0.450820                  9
# 23         0.002014          3.490626                  0
# 24         0.001006          3.018612                  0
# 25         0.001163          0.003468                  0
# 26         0.008372          9.098812                 20
# 27         0.003494          3.664426                  2
# 28         0.002729          8.620437                  0
#
# [29 rows x 26 columns]

# %%
result.columns
# Out:
# Index(['Dataset', 'Number_Of_Candidates', 'Number_of_voters',
#        'Max_Ballot_length', 'Preferred_winner', 'Upper_Bound',
#        'heuristicV1_margin', 'Our_margin', 'Blom_margin',
#        'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime',
#        'Margin_Blom=Ours', 'Upper_bound_correct', 'HeuristicV1_equl_margin',
#        'Our_number_LPS', 'Blom_number_LPS', 'Our_number_node_explored',
#        'Blom_number_node_explored', 'Our_blom_lb_calls',
#        'Blom_Leaf_node_explored', 'Our_Time_distanceTo',
#        'Blom_Time_distanceTo', 'Our_Time_lbcall', 'Blom_Time_lbcall',
#        'margin_difference'],
#       dtype='object')

# %%
avg = result.groupby(['Number_Of_Candidates'])['Dataset', 'Number_of_voters',
       'Max_Ballot_length', 'Preferred_winner', 'Upper_Bound',
       'heuristicV1_margin', 'Our_margin', 'Blom_margin',
       'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime',
       'Margin_Blom=Ours', 'Upper_bound_correct', 'HeuristicV1_equl_margin',
       'Our_number_LPS', 'Blom_number_LPS', 'Our_number_node_explored',
       'Blom_number_node_explored', 'Our_blom_lb_calls',
       'Blom_Leaf_node_explored', 'Our_Time_distanceTo',
       'Blom_Time_distanceTo', 'Our_Time_lbcall', 'Blom_Time_lbcall',
       'margin_difference'].mean()
# Out:
# C:\Users\mouin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
avg.to_csv('tempAvgmovie=10.csv')

# %%
avgDf = pd.read_csv('tempAvgmovie=10.csv')
avgDf
# Out:
#    Number_Of_Candidates  Number_of_voters  Max_Ballot_length  Upper_Bound  \
# 0                     4             472.0                4.0    60.000000
# 1                     5             499.0                4.0    58.333333
# 2                     6             517.0                4.0    41.000000
# 3                     7             521.0                4.0    41.000000
# 4                     8             523.0                4.0    40.666667
# 5                     9             525.0                4.0    47.000000
# 6                    10             528.0                4.0    61.000000
# 7                    11             530.0                4.0    53.750000
# 8                    12             541.0                4.0    24.250000
#
#    heuristicV1_margin  Our_margin  Blom_margin  heuristicV1_runtime  \
# 0           60.000000   43.500000    43.500000             0.000443
# 1           58.333333   47.333333    47.333333             0.001256
# 2           41.000000   18.000000    18.000000             0.001183
# 3           41.000000   18.000000    18.000000             0.002181
# 4           40.666667   14.000000    14.000000             0.004697
# 5           47.000000   12.333333    12.333333             0.011821
# 6           61.000000   33.000000    33.000000             0.009845
# 7           53.750000   33.500000    33.500000             0.018295
# 8           24.250000   18.750000    18.750000             0.023549
#
#    Our_runtime  Blom_runtime  ...  Blom_number_LPS  Our_number_node_explored  \
# 0     0.002025      0.043339  ...        12.500000                 14.500000
# 1     0.008298      0.090854  ...        24.666667                 26.333333
# 2     0.011652      0.083773  ...        26.000000                 38.000000
# 3     0.059601      0.315977  ...        77.666667                108.333333
# 4     0.169160      0.676328  ...       166.333333                219.666667
# 5     0.593465      2.986882  ...       521.333333                553.666667
# 6     2.533299     29.966968  ...      1848.000000               1876.250000
# 7     4.966232     95.708222  ...      2705.500000               3421.000000
# 8    14.050353    435.045225  ...      6534.250000               8594.750000
#
#    Blom_number_node_explored  Our_blom_lb_calls  Blom_Leaf_node_explored  \
# 0                  14.500000           0.000536                 2.500000
# 1                  26.333333           0.002719                 2.666667
# 2                  38.000000           0.005727                 0.333333
# 3                 108.333333           0.031297                 0.333333
# 4                 219.666667           0.097186                 1.000000
# 5                 553.666667           0.289308                 4.000000
# 6                1876.250000           0.972158                45.750000
# 7                3421.000000           2.158099                92.000000
# 8                8594.750000           6.128472               159.750000
#
#    Our_Time_distanceTo  Blom_Time_distanceTo  Our_Time_lbcall  \
# 0             0.000898              0.040545         0.000152
# 1             0.003981              0.083712         0.000390
# 2             0.004106              0.070584         0.000513
# 3             0.024717              0.263390         0.000894
# 4             0.065053              0.534815         0.001855
# 5             0.290367              2.567383         0.002092
# 6             1.537058             28.187845         0.003060
# 7             2.771517             91.285779         0.004828
# 8             7.846416            418.776085         0.003940
#
#    Blom_Time_lbcall  margin_difference
# 0          0.000886          16.500000
# 1          0.003249          11.000000
# 2          0.009457          23.000000
# 3          0.040718          23.000000
# 4          0.119211          26.666667
# 5          0.307187          34.666667
# 6          0.876738          28.000000
# 7          1.894422          20.250000
# 8          5.346786           5.500000
#
# [9 rows x 24 columns]

# %%
#import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()


x  = avgDf['Number_Of_Candidates'].to_list()
y = avgDf['heuristicV1_runtime'].to_list()
z = avgDf['Our_runtime'].to_list()
u = avgDf['Blom_runtime'].to_list()


plt.plot(x,y,color=hColor,linewidth=4)
plt.plot(x,z,color=oColor,linewidth=4)
plt.plot(x,u,color=bColor,linewidth=4)
plt.tight_layout()
# create an index for each tick position

plt.ylabel('Time (s)')
plt.xlabel('# candidates (n)')
plt.xticks([4,6,8,10,12], ['4','6','8','10','12'])

plt.legend(["AlgApprx","AlgExact","Blom"],loc='upper left')
fig.savefig(r"Figures/addition_movie_b=4_vary_n_runtime.pdf",dpi=2024,bbox_inches='tight')

# %%
#import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()


x  = avgDf['Number_Of_Candidates'].to_list()
y = avgDf['Our_Time_distanceTo'].to_list()
z = avgDf['Blom_Time_distanceTo'].to_list()

plt.plot(x,y,color=oColor,linewidth=4)
plt.plot(x,z,color=bColor,linewidth=4)
# plt.plot(x,u,color=bColor,linewidth=4)
plt.tight_layout()
# create an index for each tick position

plt.ylabel('Time (s)')
plt.xlabel('# candidates (n)')
plt.xticks([4,6,8,10,12], ['4','6','8','10','12'])

plt.legend(["DistToAddAlg","DistToIPAdd"],loc='upper left')
fig.savefig(r"Figures/addition_movie_b=4_vary_n_dto.pdf",dpi=2024,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
#plt.ylim([0,2])
box_plot = sns.boxplot(x='Number_Of_Candidates', y='Margin difference percent', data=result)
fig = box_plot.get_figure()
fig.savefig('Figure/Addition_news_margin_b=4_vary_n.pdf',dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_339000\2150250891.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 #plt.ylim([0,2])
# ----> 3 box_plot = sns.boxplot(x='Number_Of_Candidates', y='Margin difference percent', data=result)
#       4 fig = box_plot.get_figure()
#       5 fig.savefig('Figure/Addition_news_margin_b=4_vary_n.pdf',dpi=1000)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
# -> 2233                           width, dodge, fliersize, linewidth)
#    2234
#    2235     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     783                  width, dodge, fliersize, linewidth):
#     784
# --> 785         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786         self.establish_colors(color, palette, saturation)
#     787
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539                 if isinstance(var, str):
#     540                     err = f"Could not interpret input '{var}'"
# --> 541                     raise ValueError(err)
#     542
#     543             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Margin difference percent'

# %%
# #create long-form data
# df = pd.DataFrame({'points': [7, 8, 9, 12, 14, 5, 6, 6, 8, 11, 8, 9, 11, 13, 17],
#                    'team': np.repeat(['A', 'B', 'C'], 5)})

# %%
# sns.boxplot(x='team', y='points', data=df)

# %%
avg = result.groupby(['Max_Ballot_length'])['Upper_Bound','heuristicV1_margin','Our_margin','Blom_margin','heuristicV1_runtime','Our_runtime','Blom_runtime','Blom_number_node_explored','Our_number_node_explored'].mean()

# %%
avg

# %%
avg.to_csv('Addition_movie_lens_result_n=10.csv')

# %%
avgDf = pd.read_csv('Addition_movie_lens_result_n=10.csv')
avgDf
# Out:
#    Max_Ballot_length  Upper_Bound  heuristicV1_margin  Our_margin  \
# 0                  4   668.421533          668.421533  575.589416
#
#    Blom_margin  heuristicV1_runtime  Our_runtime  Blom_runtime  \
# 0   575.589416             0.005568     4.264893      6.620505
#
#    Blom_number_node_explored  Our_number_node_explored
# 0                 604.412409                604.412409

# %%
avgDf.columns = ['Max_Ballot_length','Upper_Bound', 'heuristicV1_margin', 'Our_margin', 'Blom_margin',
       'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime','Blom_number_node_explored','Our_number_node_explored']

# %%
avgDf['Max_Ballot_length'].to_list()
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()

x  = avgDf['Max_Ballot_length'].to_list()
y = avgDf['heuristicV1_margin'].to_list()
z = avgDf['Our_margin'].to_list()
u = avgDf['Blom_margin'].to_list()


plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,u)

# create an index for each tick position

plt.ylabel('Margin',fontsize=20)
plt.xlabel('Varying ballot size',fontsize=20)

plt.legend(["Heuristic","OurExact","Blom"],fontsize=18,loc='center')
fig.savefig("Addition_movie_lens_margin_n=10_vary_b.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()

x  = avgDf['Max_Ballot_length'].to_list()
y = avgDf['heuristicV1_runtime'].to_list()
z = avgDf['Our_runtime'].to_list()
u = avgDf['Blom_runtime'].to_list()


plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,u)

# create an index for each tick position

plt.ylabel('Runtime',fontsize=20)
plt.xlabel('Varying ballot size',fontsize=20)
#plt.yticks([0,2,4,6,8,10,12,14], ['0','2','4','6','8','10','12','14'])
plt.ylim(0,14)
plt.legend(["Heuristic","OurExact","Blom"],fontsize=18,loc='upper right')
fig.savefig("Addition_movie_lens_runtime_n=10_vary_b.pdf")
plt.show()

# %%
#avgDf = avgDf.drop(avgDf.index[0])

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()

x  = avgDf['Max_Ballot_length'].to_list()
y = avgDf['Our_number_node_explored'].to_list()
z = avgDf['Blom_number_node_explored'].to_list()
#u = avgDf['Blom_runtime'].to_list()


plt.plot(x,y,color='orange')
plt.plot(x,z,color='green')
#plt.plot(x,u)

# create an index for each tick position

plt.ylabel('Node Explored',fontsize=20)
plt.xlabel('Varying ballot size',fontsize=20)
#plt.yticks([0,2,4,6,8,10,12,14], ['0','2','4','6','8','10','12','14'])
#plt.ylim(0,14)
plt.legend(["OurExact","Blom"],fontsize=18,loc='upper right')
fig.savefig("Addition_movie_lens_node_explored_n=10_vary_b.pdf")
plt.show()

# %%
########################################### vary n #############################################################################

# %%
result = pd.read_csv(r"Addiiton_adressa_boxplot.csv")

# %%
result
# Out:
#      Unnamed: 0             Dataset  Number_Of_Candidates  Number_of_voters  \
# 0            10  adressa=4_ballot=4                     4               457
# 1            12  adressa=4_ballot=4                     4               457
# 2            15  adressa=4_ballot=4                     4               457
# 3            25  adressa=4_ballot=4                     4               457
# 4            31  adressa=4_ballot=4                     4               457
# ..          ...                 ...                   ...               ...
# 543        1282  adressa=8_ballot=4                     8              3246
# 544        1283  adressa=8_ballot=4                     8              3246
# 545        1284  adressa=8_ballot=4                     8              3246
# 546        1285  adressa=8_ballot=4                     8              3246
# 547        1286  adressa=8_ballot=4                     8              3246
#
#      Max_Ballot_length     Preferred_winner  Upper_Bound  heuristicV1_margin  \
# 0                    4             virginia           38                  38
# 1                    4        new hampshire          113                 113
# 2                    4  rio grande do norte           25                  25
# 3                    4              georgia           38                  38
# 4                    4                 faro           38                  38
# ..                 ...                  ...          ...                 ...
# 543                  4       espirito santo         1481                1481
# 544                  4      valle del cauca          499                 499
# 545                  4          puerto rico         1481                1481
# 546                  4               huelva         1487                1487
# 547                  4              venezia          499                 499
#
#      Our_margin  Blom_margin  ...  Our_number_LPS  Blom_number_LPS  \
# 0            38           38  ...               0                5
# 1           104          104  ...               0                8
# 2             5            5  ...               0               12
# 3            38           38  ...               0                5
# 4            38           38  ...               0                5
# ..          ...          ...  ...             ...              ...
# 543        1481         1481  ...               0             1970
# 544         499          499  ...               0             1335
# 545         499          499  ...               0             2923
# 546        1439         1439  ...               0             1789
# 547         499          499  ...               0             1335
#
#      Our_number_node_explored  Blom_number_node_explored  Our_blom_lb_calls  \
# 0                           6                          6           0.000316
# 1                           9                          9           0.000406
# 2                          14                         14           0.001310
# 3                           6                          6           0.000330
# 4                           6                          6           0.000396
# ..                        ...                        ...                ...
# 543                      1971                       1971           2.204612
# 544                      1588                       1588           1.927678
# 545                      2924                       2924           3.616570
# 546                      1790                       1790           2.014206
# 547                      1588                       1588           1.993866
#
#      Blom_Leaf_node_explored  Our_Time_distanceTo  Blom_Time_distanceTo  \
# 0                          0             0.001179              0.054172
# 1                          1             0.002059              0.031041
# 2                          1             0.004929              0.024185
# 3                          0             0.001230              0.005182
# 4                          0             0.001516              0.007381
# ..                       ...                  ...                   ...
# 543                      206            13.738980             22.674971
# 544                        0             8.404814             11.004128
# 545                      238            19.873486             30.068558
# 546                      174            12.555670             20.071913
# 547                        0             8.428692             10.902131
#
#      Our_Time_lbcall  Blom_Time_lbcall
# 0           0.000105          0.000438
# 1           0.000103          0.000744
# 2           0.000209          0.000990
# 3           0.000126          0.000457
# 4           0.000131          0.000542
# ..               ...               ...
# 543         0.002579          1.770755
# 544         0.002397          1.623740
# 545         0.012844          2.930251
# 546         0.002712          1.609556
# 547         0.005824          1.614774
#
# [548 rows x 26 columns]

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'Dataset', 'Number_Of_Candidates', 'Number_of_voters',
#        'Max_Ballot_length', 'Preferred_winner', 'Upper_Bound',
#        'heuristicV1_margin', 'Our_margin', 'Blom_margin',
#        'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime',
#        'Margin_Blom=Ours', 'Upper_bound_correct', 'HeuristicV1_equl_margin',
#        'Our_number_LPS', 'Blom_number_LPS', 'Our_number_node_explored',
#        'Blom_number_node_explored', 'Our_blom_lb_calls',
#        'Blom_Leaf_node_explored', 'Our_Time_distanceTo',
#        'Blom_Time_distanceTo', 'Our_Time_lbcall', 'Blom_Time_lbcall'],
#       dtype='object')

# %%
avg = result.groupby(['Number_Of_Candidates'])['Upper_Bound','heuristicV1_margin','Our_margin','Blom_margin','heuristicV1_runtime','Our_runtime','Blom_runtime','Blom_number_node_explored','Our_number_node_explored','Our_Time_distanceTo','Blom_Time_distanceTo'].mean()
# Out:
# C:\Users\mouin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
avg
# Out:
#                       Upper_Bound  heuristicV1_margin   Our_margin  \
# Number_Of_Candidates
# 4                       51.488889           51.488889    37.266667
# 5                      283.017094          283.017094   268.683761
# 6                      526.178862          526.178862   465.349593
# 7                     1025.904762         1025.904762   859.944444
# 8                     1462.652174         1462.652174  1250.456522
#
#                       Blom_margin  heuristicV1_runtime  Our_runtime  \
# Number_Of_Candidates
# 4                       37.266667             0.000408     0.003562
# 5                      268.683761             0.001374     0.053289
# 6                      465.349593             0.003775     0.403325
# 7                      859.944444             0.007340     2.279998
# 8                     1250.456522             0.015919    21.670840
#
#                       Blom_runtime  Blom_number_node_explored  \
# Number_Of_Candidates
# 4                         0.019779                   8.322222
# 5                         0.154483                  41.068376
# 6                         0.669374                 131.471545
# 7                         3.562910                 476.269841
# 8                        33.444812                2711.771739
#
#                       Our_number_node_explored  Our_Time_distanceTo  \
# Number_Of_Candidates
# 4                                     8.322222             0.002380
# 5                                    41.068376             0.043455
# 6                                   131.471545             0.332303
# 7                                   476.269841             1.909484
# 8                                  2711.771739            18.486905
#
#                       Blom_Time_distanceTo
# Number_Of_Candidates
# 4                                 0.018212
# 5                                 0.140844
# 6                                 0.593943
# 7                                 3.155601
# 8                                29.957593

# %%
avg.to_csv(r'Addition_news_b=4_int1.csv')

# %%
avgDf = pd.read_csv(r'Addition_news_b=4_int1.csv')
avgDf
# Out:
#    Number_Of_Candidates  Upper_Bound  heuristicV1_margin   Our_margin  \
# 0                     4    51.488889           51.488889    37.266667
# 1                     5   283.017094          283.017094   268.683761
# 2                     6   526.178862          526.178862   465.349593
# 3                     7  1025.904762         1025.904762   859.944444
# 4                     8  1462.652174         1462.652174  1250.456522
#
#    Blom_margin  heuristicV1_runtime  Our_runtime  Blom_runtime  \
# 0    37.266667             0.000408     0.003562      0.019779
# 1   268.683761             0.001374     0.053289      0.154483
# 2   465.349593             0.003775     0.403325      0.669374
# 3   859.944444             0.007340     2.279998      3.562910
# 4  1250.456522             0.015919    21.670840     33.444812
#
#    Blom_number_node_explored  Our_number_node_explored  Our_Time_distanceTo  \
# 0                   8.322222                  8.322222             0.002380
# 1                  41.068376                 41.068376             0.043455
# 2                 131.471545                131.471545             0.332303
# 3                 476.269841                476.269841             1.909484
# 4                2711.771739               2711.771739            18.486905
#
#    Blom_Time_distanceTo
# 0              0.018212
# 1              0.140844
# 2              0.593943
# 3              3.155601
# 4             29.957593

# %%
avgDf.columns = ['Number_Of_Candidates','Upper_Bound', 'heuristicV1_margin', 'Our_margin', 'Blom_margin',
       'heuristicV1_runtime', 'Our_runtime', 'Blom_runtime','Blom_number_node_explored','Our_number_node_explored','Our_Time_distanceTo','Blom_Time_distanceTo']

# %%
# import matplotlib.pyplot as plt
# #plt.rcParams.update({'font.size': 18})
# fig, ax = plt.subplots(nrows=1, ncols=1)
# fig.tight_layout()


# x  = avgDf['Number_Of_Candidates'].to_list()
# y = avgDf['heuristicV1_margin'].to_list()
# z = avgDf['Our_margin'].to_list()
# u = avgDf['Blom_margin'].to_list()


# plt.plot(x,y)
# plt.plot(x,z)
# plt.plot(x,u)

# # create an index for each tick position

# plt.ylabel('Margin',fontsize=18)
# plt.xlabel('Varying #candidates',fontsize=18)
# #plt.yticks([0,5,10,15,20], ['0','5','10','15','20'])

# plt.legend(["Heuristic","OurExact","Blom"],fontsize=18,loc='center')
# fig.savefig("Figure/Addition_books_margin_b=4_vary_n.pdf")

# %%
# yvals = [math.ceil(x) for x in result['heuristicV1_margin'].to_list()] 
# zvals = [math.ceil(x) for x in result['Our_margin'].to_list()]
# kvals =  [math.ceil(x) for x in result['Blom_margin'].to_list()]
# ticklabels = tuple(result['Number_Of_Candidates'].to_list())
# ticklabels

# %%
x  = avgDf['Number_Of_Candidates'].to_list()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = len(x)
ind = np.arange(N)  # the x locations for the groups
width = 0.27     # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

x  = avgDf['Number_Of_Candidates'].to_list()
y = avgDf['heuristicV1_margin'].to_list()
z = avgDf['Our_margin'].to_list()
u = avgDf['Blom_margin'].to_list()
ticklabels = []
for i in x:
    s = "n="+str(i)
    ticklabels.append(s)


rects1 = ax.bar(ind, y, width, color=hColor)
rects2 = ax.bar(ind+width, z, width, color=oColor)
rects3 = ax.bar(ind+width*2, u, width, color=bColor)

ax.set_ylabel('Margin')
ax.set_xticks(ind+width)
ax.set_xticklabels( ticklabels )
ax.tick_params(axis='both', which='major', labelsize=10)

ax.legend( (rects1[0], rects2[0], rects3[0]), ('Heuristic', 'OurExact', 'Blom') )
plt.ylim(0,2000)
plt.savefig('Figure/Addition_news_margin_b=4_vary_n.pdf',dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()


x  = avgDf['Number_Of_Candidates'].to_list()
y = avgDf['heuristicV1_runtime'].to_list()
z = avgDf['Our_runtime'].to_list()
u = avgDf['Blom_runtime'].to_list()


plt.plot(x,y,color=hColor)
plt.plot(x,z,color=oColor)
plt.plot(x,u,color=bColor)

# create an index for each tick position

plt.ylabel('Time (s)',fontsize=18)
plt.xlabel('Varying #candidates',fontsize=18)
#plt.yticks([0,5,10,15,20], ['0','5','10','15','20'])

plt.legend(["Heuristic","OurExact","Blom"],fontsize=18,loc='upper left')
fig.savefig(r"Figure/Addition_news_runtime_b=4_vary_n.pdf",dpi=1000)

# %%
# import matplotlib.pyplot as plt

# #plt.rcParams.update({'font.size': 18})
# fig, ax = plt.subplots(nrows=1, ncols=1)
# fig.tight_layout()


# x  = avgDf['Number_Of_Candidates'].to_list()
# y = avgDf['Our_number_node_explored'].to_list()
# z = avgDf['Blom_number_node_explored'].to_list()
# #u = avgDf['Blom_runtime'].to_list()


# plt.plot(x,y)
# plt.plot(x,z)
# #plt.plot(x,u)

# # create an index for each tick position

# plt.ylabel('# Node explored',fontsize=18)
# plt.xlabel('Varying #candidates',fontsize=18)
# #plt.yticks([0,5,10,15,20], ['0','5','10','15','20'])

# plt.legend(["OurExact","Blom"],fontsize=18,loc='upper left')
# fig.savefig(r"Figure/Addition_books_node_explored_b=4_vary_n.pdf")

# %%
import numpy as np

N = len(x)
ind = np.arange(N)  # the x locations for the groups
width = 0.27     # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

x  = avgDf['Number_Of_Candidates'].to_list()
y = avgDf['Our_number_node_explored'].to_list()
z = avgDf['Blom_number_node_explored'].to_list()
ticklabels = []
for i in x:
    s = "n="+str(i)
    ticklabels.append(s)


rects1 = ax.bar(ind, y, width, color=oColor)
rects2 = ax.bar(ind+width, z, width, color=bColor)
#rects3 = ax.bar(ind+width*2, u, width, color='b')

ax.set_ylabel('# Node explored')
ax.set_xticks(ind+width)
ax.set_xticklabels( ticklabels )
ax.tick_params(axis='both', which='major', labelsize=10)

ax.legend( (rects1[0], rects2[0]), ('Heuristic', 'OurExact') )
#plt.ylim(1700,1850)
plt.savefig('Figure/Addition_news_node_explored_b=4_vary_n.pdf',dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.tight_layout()


x  = avgDf['Number_Of_Candidates'].to_list()
#y = avgDf['heuristicV1_runtime'].to_list()
z = avgDf['Our_Time_distanceTo'].to_list()
u = avgDf['Blom_Time_distanceTo'].to_list()


#plt.plot(x,y)
plt.plot(x,z,color=oColor)
plt.plot(x,u,color=bColor)

# create an index for each tick position

plt.ylabel('Time (s) for distanceTo',fontsize=18)
plt.xlabel('Varying #candidates',fontsize=18)
#plt.yticks([0,5,10,15,20], ['0','5','10','15','20'])

plt.legend(["OurExact","Blom"],fontsize=18,loc='upper left')
fig.savefig(r"Figure/Addition_news_runtime_distanceTo_b=4_vary_n.pdf",dpi=1000)
