# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.size"] = "26"
#plt.rcParams['savefig.facecolor'] = "0.5"
plt.tight_layout()

# %%
result = pd.read_csv("AntiPlurality/AntiPlurality_MovieLens.csv")

# %%
result
# Out:
#      n       irv  plurality
# 0   50  0.147368   0.457895
# 1   75  0.082500   0.307500
# 2  100  0.061702   0.247872

# %%
import numpy as np

x  = result['n'].to_list()
y = result['irv'].to_list()
z = result['plurality'].to_list()

N = len(x)
ind = np.arange(N)  # the x locations for the groups
width = 0.27     # the width of the bars

fig = plt.figure()
plt.tight_layout()
ax = fig.add_subplot(111)


ticklabels = []
for i in x:
    #s = "n="+str(i)
    s = str(i)
    ticklabels.append(s)


rects1 = ax.bar(ind, y, width)#, color=oColor)
rects2 = ax.bar(ind+width, z, width)#, color=bColor)
#rects3 = ax.bar(ind+width*2, u, width, color='b')

ax.set_ylabel('Anti-Plurality Index')
ax.set_xlabel('# candidates (n)')
ax.set_xticks(ind+width)
ax.set_xticklabels( ticklabels )
ax.set_yticks([0,0.5,1],['0','0.5','1.0'])
ax.tick_params(axis='both', which='major', labelsize=20)

ax.legend( (rects1[0], rects2[0]), ('IRV', 'Plurality') )
#plt.ylim(1700,1850)
plt.savefig('Figures/antiplurality_movieLens.pdf',dpi=2024,bbox_inches='tight')
plt.show()
